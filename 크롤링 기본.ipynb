# %% [raw]
# 1. 라이브러리 임포트
# import requests
# from bs4 import BeautifulSoup
# 2. 웹페이지 가져오기
# res = requests.get('url')
# 3. 웹 페이지 파싱
# soup = BdautifulSoup(res.content, 'html.parser')
# 4. 필요한 데이터 추출
# mydata = soup.find('title')
# 5. 추출한 데이터 활용
# print(mydata.get_text())
#
# 크롤링 - 원하는 정보를 자동으로 추출하는 방법

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://n.news.naver.com/mnews/article/052/0002139519')
res.content
# Out:
# b'<!doctype html>\n<html lang="ko" data-useragent="python-requests/2.32.3">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="\'\xea\xb4\x80\xec\x84\xb8\xed\x8f\xad\xed\x83\x84\' \xec\x9c\x84\xed\x98\x91\xeb\xb0\x9b\xec\x9d\x80 \xec\xba\x90\xeb\x82\x98\xeb\x8b\xa4, \xeb\xaf\xb8\xea\xb5\xad \xec\xa0\x9c\xed\x92\x88\xec\x97\x90 \xeb\xb3\xb4\xeb\xb3\xb5 \xea\xb4\x80\xec\x84\xb8 \xea\xb2\x80\xed\x86\xa0">\n\t\t<meta property="og:type" content="article">\n\t\t<meta property="og:url" content="https://n.news.naver.com/mnews/article/052/0002139519">\n\t\t<meta property="og:image" content="https://imgnews.pstatic.net/image/052/2025/01/11/202501111557486972_t_20250111160011558.jpg?type&#x3D;w800">\n\t\t<meta property="og:description" content="\xeb\x8f\x84\xeb\x84\x90\xeb\x93\x
# ...

# %%
soup = BeautifulSoup(res.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html data-useragent="python-requests/2.32.3" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="'관세폭탄' 위협받은 캐나다, 미국 제품에 보복 관세 검토" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/mnews/article/052/0002139519" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/052/2025/01/11/202501111557486972_t_20250111160011558.jpg?type=w800" property="og:image"/>
# <meta content="도널드 트럼프 미국 대통령 당선인에게 25% 관세 폭탄 위협을 받은 캐나다가 맞대응 카드를 준비하고 있다고 미국 CNN이 보도했습니다. CNN 방송은 현지 시간 10일 캐나다가 트럼프 행정부 출범 후 실제로 캐나다 " property="og:description"/>
# <meta content="YTN | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %%
mydata = soup.find('title')
mydata.get_text()
# Out:
# "'관세폭탄' 위협받은 캐나다, 미국 제품에 보복 관세 검토"

# %%
from bs4 import BeautifulSoup
html = "<html> \
            <body> \
                <h1 id='title'>[1] 크롤링?</h1> \
                <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출</p> \
                <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p> \
            </body> \
        </html>"

soup = BeautifulSoup(html, "html.parser")
#data = soup.find('p', class_='cssstyle')
#data = soup.find('p', attrs={'id': 'body', 'align':'center'})
data = soup.find_all('p')
for item in data:
    print (item.string)
# Out:
# 웹페이지에서 필요한 데이터를 추출
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.bbc.com/news/articles/c897l7wyzj5o')

# Find the span element with the specific class
mydata = soup.find_all('span')

for item in mydata:
    print (item.get_text())
# Out:
# Home
# News
# Sport
# Business
# Innovation
# Culture
# Arts
# Travel
# Earth
# Video
# Live
# Audio
# Weather
# Newsletters
# Getty Images
# Related
# 3 hrs ago
# US & Canada
# 9 hrs ago
# US & Canada
# 10 hrs ago
# US & Canada
# More
# 4 hrs ago
# 4 hrs ago
# England
# 6 hrs ago
# 6 hrs ago
# US & Canada
# 13 hrs ago
# 13 hrs ago
# US & Canada
# 14 hrs ago
# 14 hrs ago
# US & Canada
# 16 hrs ago
# 16 hrs ago
# US & Canada

# %%
''' HTML/CSS 언어 기반 크롤링

data = soup.find('h1', 'tit_view')
print (data.get_text())

data = soup.find_all('span', 'txt_info')
print(data.get_text())

data = soup.find_all('span', 'txt_info')
for item in data:
        print(item.get_text())

data = soup.find_all('span', 'txt_info')
print(data[1].get_text()) '''
# Out:
# " HTML/CSS 언어 기반 크롤링\n\ndata = soup.find('h1', 'tit_view')\nprint (data.get_text())\n\ndata = soup.find_all('span', 'txt_info')\nprint(data.get_text())\n\ndata = soup.find_all('span', 'txt_info')\nfor item in data:\n        print(item.get_text())\n\ndata = soup.find_all('span', 'txt_info')\nprint(data[1].get_text()) "

# %%
# 추출한 것에서 또 추출

''' import requests
from bs4 import BeautifulSoup

res = requests.get('url')
soup = BeautifulSoup(res.content, 'html.parser')

section=soup.find('ul', id = '감싸고 있는 코드')
titles = section.find_all('li', 'course')
for title in titles:
    print(title.get_text()) '''

# %%
# 문자열 함수와 함께 사용

''' section = soup.find('ul', id='dev_course_list')
titles = section.find_all('li', 'course')
for index, title in enumerate(titles):
    print(index + 1, title.get_text().split('-')[-1].split('[')[0].strip()) '''
    #split('['): [ 문자열 기준으로 index를 나눠서 추출

# %%
# strip() 함수 사용

''' section = soup.find('ul', id='dev_course_list')
titles = section.find_all('li', 'course')
for index, title in enumerate(titles):
    print(str(index + 1), + '.', title.get_text().split('-')[-1].split('[')[0].strip()) '''

# %% [markdown]
# #CSS Selector 사용
#
# * select() 안에 태그 또는 CSS class 이름등 넣어줌
# * 결과값은 리스트 형태로 반환
#    - 매칭되는 첫번째 데이터만 얻고자 할 때는 select_one(), 이 때는 해당 아이템 객체가 리턴

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css.html')
soup = BeautifulSoup(res.content,
'html.parser')
items = soup.select('li')
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css.html')
soup = BeautifulSoup(res.content,
'html.parser')
items = soup.select('html body h1') # 스페이스로 구분 -> 하위로 들어가는 것
for item in items:
    print (item.get_text())
# Out:
# 잔재미코딩 크롤링 테스트 페이지 (커리큘럼)

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css.html')
soup = BeautifulSoup(res.content,
'html.parser')
items = soup.select('ul > li') # ul 태그 바로 아래에 있는 li 태그만 선택
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css.html')
soup = BeautifulSoup(res.content,
'html.parser')
items = soup.select('.course') # class가 course인 것만 선택
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
# id 선택자

import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css.html')
soup = BeautifulSoup(res.content,
'html.parser')
items = soup.select('#start') # id가 start인 것만 선택
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css.html')
soup = BeautifulSoup(res.content,
'html.parser')
items = soup.select('li.course.paid') # li 태그 중 class가 course와 paid인 것만 선택. 중복 클래스 선택
for item in items:
    print (item.get_text())
# Out:
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
# 복합 선택자

import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css.html')
soup = BeautifulSoup(res.content,
'html.parser')
items = soup.select('ul#hobby_course_list li.course') # id가 hobby_course_list인 ul 태그 바로 아래에 있는 li 태그 중 class가 course인 것만 선택
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기

# %%
# select_one() 함수: 선택자로 요소 하나만 추출

from bs4 import BeautifulSoup
import requests
res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css.html')
soup = BeautifulSoup(res.content,'html.parser')
item = soup.select_one('ul#dev_course_list > li.course.paid')
print (item.get_text())
# Out:
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
# 추출한 요소에서 다시 추출 - find(), select()

from bs4 import BeautifulSoup
import requests
res = requests.get('https://davelee-fun.github.io/blog/crawl_html_css.html')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('tr')
for item in items:
    columns = item.select('td')
    row_str = ''
    for column in columns:
        row_str += ', ' + column.get_text()
    print (row_str[2:])
# Out:
# 일정, 커리큘럼 타이틀, 난이도
# 5.1 ~ 6.15, 나만의 엣지있는 블로그 사이트 만들기 (취미로 익히는 IT), 초급
# 6.16 ~ 7.31, 파이썬과 데이터과학 첫걸음 (IT 기본기 익히기), 중급
